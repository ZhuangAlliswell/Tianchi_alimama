# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.cross_validation import train_test_split
import scipy as sp
path='/home/student303/zz/almama/'
# Out:
# /home/student303/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_hdf(path+ 'somefeature/one_column_train_feature.h5', key = 'a')
test = pd.read_hdf(path+ 'somefeature/one_column_test_feature.h5', key = 'a')
#y_train = pd.read_csv(path + 'somefeature/y_train.csv')

# %%
droplist = ['item_category_list',
            'item_property_list',
            'user_id',
            'context_id',
           #'context_page_id',
            'predict_category_property',
            #'shop_id'
           ]
df_test = test.drop(droplist, axis=1)
df_train = train.drop(droplist, axis=1)
# df_train.drop('is_trade', axis=1, inplace = True)
combine = [df_train, df_test]

# %%
df_train.columns
# Out:
# Index(['context_page_id', 'context_timestamp', 'day', 'hour', 'instance_id',
#        'is_trade', 'item_brand_id', 'item_category_hash', 'item_city_id',
#        'item_collected_level', 'item_id', 'item_price_level', 'item_pv_level',
#        'item_sales_level', 'min', 'second', 'shop_id', 'shop_review_num_level',
#        'shop_review_positive_rate', 'shop_score_delivery',
#        'shop_score_description', 'shop_score_service', 'shop_star_level',
#        'user_age_level', 'user_gender_id', 'user_occupation_id',
#        'user_star_level', 'context_page_id_cvr', 'hour_cvr',
#        'item_brand_id_cvr', 'item_category_hash_cvr', 'item_category_list_cvr',
#        'item_city_id_cvr', 'item_collected_level_cvr', 'item_id_cvr',
#        'item_price_level_cvr', 'item_property_list_cvr', 'item_pv_level_cvr',
#        'item_sales_level_cvr', 'min_cvr', 'second_cvr', 'shop_id_cvr',
#        'shop_review_num_level_cvr', 'shop_review_positive_rate_cvr',
#        'shop_score_delivery_cvr', 'shop_score_description_cvr',
#        'shop_score_service_cvr', 'shop_star_level_cvr', 'user_age_level_cvr',
#        'user_gender_id_cvr', 'user_id_cvr', 'user_occupation_id_cvr',
#        'user_star_level_cvr'],
#       dtype='object')

# %%
def logloss(act, pred):
    epsilon = 1e-15
    pred = sp.maximum(epsilon, pred)
    pred = sp.minimum(1-epsilon, pred)
    ll = sum(act*sp.log(pred) + sp.subtract(1,act)*sp.log(sp.subtract(1,pred)))
    ll = ll * -1.0/len(act)
    return ll

# %% [markdown]
# ## train LGBM model

# %%
train_train = df_train[df_train.day != 24]
train_valid = df_train[df_train.day == 24]

train_X = train_train.drop('is_trade', axis=1)
train_y = train_train['is_trade'].values

valid_X = train_valid.drop('is_trade', axis=1)
valid_y = train_valid['is_trade'].values

#train_X, valid_X, train_y, valid_y = train_test_split(df_train, y_train['is_trade'], test_size = 0.1, random_state = 144) 
# train_dataframe = df_train[df_train.day != 24]
d_train = lgb.Dataset(train_X, label=train_y)
d_valid = lgb.Dataset(valid_X, label=valid_y)
watchlist = [d_train, d_valid]

# %%
print('LGBM training')
#lgb_train = lgb.Dataset(df_train.values, label = y_train.is_trade)
params = {
    'task': 'train',
    #'boosting_type': 'gbdt',
    #'objective': 'binary',
    'metric': 'binary_logloss',
#    'max_depth':3,
#    'num_leaves': 6,
#    'min_data_in_leaf':1,
    #'max_bin':150,  
    'learning_rate': 0.1,
    'feature_fraction': 1.0,
    'bagging_fraction': 1.0,
    #'bagging_freq': 5,
    'verbose': 0,
}
model = lgb.train(params, train_set=d_train, num_boost_round=6000, valid_sets=watchlist, \
                  early_stopping_rounds=500, verbose_eval=50)
print('LGBM training done')
# Out:
# LGBM training
# Train until valid scores didn't improve in 500 rounds.
# [50]	training's binary_logloss: 0.0814758	valid_1's binary_logloss: 0.082647
# [100]	training's binary_logloss: 0.0769995	valid_1's binary_logloss: 0.084599
# [150]	training's binary_logloss: 0.0735298	valid_1's binary_logloss: 0.0882021
# [200]	training's binary_logloss: 0.0704878	valid_1's binary_logloss: 0.0927801
# [250]	training's binary_logloss: 0.0680893	valid_1's binary_logloss: 0.0972571
# [300]	training's binary_logloss: 0.0657737	valid_1's binary_logloss: 0.10002
# [350]	training's binary_logloss: 0.0638599	valid_1's binary_logloss: 0.103002
# [400]	training's binary_logloss: 0.0621766	valid_1's binary_logloss: 0.104787
# [450]	training's binary_logloss: 0.0605724	valid_1's binary_logloss: 0.109488
# [500]	training's binary_logloss: 0.0590814	valid_1's binary_logloss: 0.113271
# Early stopping, best iteration is:
# [34]	training's binary_logloss: 0.0835049	valid_1's binary_logloss: 0.0823637
# LGBM training done

# %%
# %matplotlib inline
lgb.plot_importance(model)

# %% [markdown]
# ## predict test prob

# %%
instance_id=df_test.instance_id.values 
prob = model.predict(df_test, num_iteration=model.best_iteration )

output=pd.DataFrame({'instance_id':instance_id,'predicted_score':prob})  
output['predicted_score'] = output['predicted_score'].apply(lambda x:round(x,10))
print(output.head())
#output.to_hdf(path + 'output/submission.h5',index=False)
#print('the output path is '+path)
# Out:
#            instance_id  predicted_score
# 0  2475218615076601065          0.00791
# 1   398316874173557226          0.01633
# 2  6586402638209028583          0.01563
# 3  1040996105851528465          0.01780
# 4  6316278569655873454          0.01189
